# %%
# %sql
create table emp6(id int, name string);
insert into emp values(1,'abc'),(2,'xyz');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
df = spark.readStream.format("delta").table("emp6")

# %%
checkpoint_path = "/Volumes/klrdatabrick3/default/klrvolume/checkpoint/4"
output_path = "/Volumes/klrdatabrick3/default/klrvolume/output8"

# %%
import uuid
def foreach_batch_function(df, epoch_id):
    #array_id = df.collect()[0][0]
    #if array_id == 3:
        #raise Exception("Test Exception")
 
    df.write.mode("append").json(output_path + "/" +str(uuid.uuid4()))
 
 
query = (df.writeStream.foreachBatch(foreach_batch_function).option("checkpointLocation", checkpoint_path).start())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
